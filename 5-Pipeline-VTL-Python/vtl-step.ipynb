# %%
taxi := loadSas("data/nyc_taxi.sas7bdat");

taxi_meta := taxi  [calc identifier vendor_id := vendor_id, identifier pickup_at := pickup_at]
                            [keep total_amount];

ratio <- ratio_to_report(taxi_meta over(partition by vendor_id)) * 1000000;

w := writeCSV("vtl-step-output", ratio);
# Out:
# Dataset 'taxi' loaded from 'data/nyc_taxi.sas7bdat' (sas, 18 columns)
# Dataset 'w' written to 'vtl-step-output' (csv)
# taxi_meta calculated
# ratio calculated
